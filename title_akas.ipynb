# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('title.akas.tsv', sep="\t", index_col="titleId", nrows=None)
# Out:
# /home/russ/git/CGC-Machine_Learning_on_AWS/.venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#            ordering                      title region language        types  \
# titleId
# tt0000001         1                 Карменсіта     UA       \N  imdbDisplay
# tt0000001         2                 Carmencita     DE       \N           \N
# tt0000001         3  Carmencita - spanyol tánc     HU       \N  imdbDisplay
# tt0000001         4                 Καρμενσίτα     GR       \N  imdbDisplay
# tt0000001         5                 Карменсита     RU       \N  imdbDisplay
# ...             ...                        ...    ...      ...          ...
# tt9916852         4                エピソード #3.20     JP       ja           \N
# tt9916852         5             Episódio #3.20     PT       pt           \N
# tt9916852         6             Episodio #3.20     IT       it           \N
# tt9916852         7               एपिसोड #3.20     IN       hi           \N
# tt9916856         1                   The Wind     DE       \N           \N
#
#               attributes isOriginalTitle
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23944188 entries, tt0000001 to tt9916856
# Data columns (total 7 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ordering         int64
#  1   title            object
#  2   region           object
#  3   language         object
#  4   types            object
#  5   attributes       object
#  6   isOriginalTitle  object
# dtypes: int64(1), object(6)
# memory usage: 1.4+ GB

# %%
df.shape
# Out:
# (23944188, 7)

# %%
df.describe()
# Out:
#            ordering
# count  2.394419e+07
# mean   4.036208e+00
# std    3.345967e+00
# min    1.000000e+00
# 25%    2.000000e+00
# 50%    4.000000e+00
# 75%    6.000000e+00
# max    1.460000e+02

# %%
df.isnull().sum()
# Out:
# ordering            0
# title               2
# region             96
# language            0
# types               0
# attributes          0
# isOriginalTitle     0
# dtype: int64

# %%
df = df.replace(r'^\\N*$', np.nan, regex=True)

# %%
df.isnull().sum()
# Out:
# ordering                  0
# title                     2
# region               583433
# language            4118884
# types              22077646
# attributes         23734811
# isOriginalTitle        2189
# dtype: int64

# %%
df['region'].unique()
# Out:
# array(['UA', 'DE', 'HU', 'GR', 'RU', 'US', nan, 'JP', 'FR', 'RO', 'GB',
#        'PT', 'RS', 'ES', 'UY', 'IT', 'AR', 'FI', 'PL', 'BR', 'XWW', 'DK',
#        'TR', 'XEU', 'SK', 'CZ', 'SE', 'MX', 'XYU', 'AT', 'VE', 'CSHH',
#        'SI', 'AU', 'TW', 'LT', 'IN', 'CA', 'NL', 'NO', 'CO', 'IR', 'BG',
#        'BE', 'DZ', 'CH', 'NZ', 'BF', 'XWG', 'VN', 'XSA', 'SUHH', 'EE',
#        'IS', 'HR', 'DDDE', 'XKO', 'CL', 'EG', 'HK', 'GE', 'BY', 'BA',
#        'PE', 'PA', 'CN', 'TJ', 'XSI', 'YUCS', 'IE', 'IL', 'LV', 'CU',
#        'AL', 'BO', 'ID', 'ZA', 'KR', 'MY', 'SG', 'BUMM', 'XPI', 'BJ',
#        'PR', 'CM', 'AZ', 'TH', 'DO', 'EC', 'MA', 'PH', 'GL', 'LI', 'LU',
#        'PY', 'MZ', 'BM', 'JM', 'MD', 'CR', 'GT', 'LB', 'IQ', 'TM', 'MK',
#        'TN', 'NG', 'HT', 'AM', 'SN', 'GH', 'CI', 'JO', 'KG', 'PK', 'LK',
#        'NE', 'GN', 'VDVN', 'TD', 'SO', 'SD', 'MC', 'CG', 'TT', 'GA', 'BS',
#        'LY', 'SY', 'AO', 'KH', 'SV', 'MR', 'AF', 'MG', 'ML', 'GY', 'CY',
# ...

# %%
df = df[
    (df['language'].isin(['en']))
    &
    (df['region'].isin(['US', 'CA', 'GB', 'ZA']))
]

# %%
df.sort_values(by=["ordering"], ascending=False)
# Out:
#            ordering                               title region language  \
# titleId
# tt0168366       109                             Pokémon     CA       en
# tt0076759        99  Star Wars: Episode IV - A New Hope     US       en
# tt0103369        83             Bishôjo senshi Sêrâ Mûn     CA       en
# tt8187756        75                           Game Over     US       en
# tt0087332        70                        Ghostbusters     ZA       en
# ...             ...                                 ...    ...      ...
# tt5890536         1                     I Need 2 Pee 25     CA       en
# tt5887946         1             Robopon 2: Ring Version     CA       en
# tt5887936         1            Robopon 2: Cross Version     CA       en
# tt5887908         1                Robopon: Sun Version     CA       en
# tt3522052         1                     Ex on the Beach     CA       en
#
#                  types            attributes isOriginalTitle
# titleId
# ...
